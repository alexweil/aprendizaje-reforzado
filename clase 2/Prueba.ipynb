# %%
import gym

env = gym.make('MountainCar-v0')

for i_episode in range(1):
    
    observation = env.reset()
    print('initial observation: %s' % observation)
    
    for t in range(100):
        
        #env.render()
        
        action = env.action_space.sample()
        print('action: %s' % action)
        
        observation, reward, done, info = env.step(action)
        print('observation: %s' % observation)
        print('reward: %s' % reward)
        print('done: %s' % done)
        print('info: %s' % info)
        
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            break
            
        print('------------------------------')
            
env.close()
# Out:
# initial observation: [-0.50917908  0.        ]
# action: 2
# observation: [-0.50828719  0.00089189]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.5065101   0.00177709]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-0.50586112  0.00064898]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.50434511  0.00151601]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-5.03973422e-01  3.71688734e-04]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.50274884  0.00122458]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.50068053  0.00206831]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-0.49978397  0.00089656]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-5.00065867e-01 -2.81899602e-04]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-5.00524117e-01 -4.58249836e-04]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-5.00155289e-01  3.68828408e-04]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.49896214  0.00119315]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.4969536   0.00200854]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.49414469  0.00280891]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.49155639  0.0025883 ]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.48920804  0.00234835]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.48711717  0.00209088]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-0.48629936  0.00081781]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.48476071  0.00153865]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.48251269  0.00224802]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-0.48157204  0.00094065]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.48094575  0.00062629]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-4.80638487e-01  3.07262345e-04]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-4.80652536e-01 -1.40485811e-05]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-0.48198779 -0.00133526]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.48263432 -0.00064653]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-4.82587306e-01  4.70118427e-05]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.48184711  0.0007402 ]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-4.81419223e-01  4.27881871e-04]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-0.48230684 -0.00088762]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-0.48450336 -0.00219652]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.48699243 -0.00248906]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.48975549 -0.00276306]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.49277193 -0.00301645]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.49501925 -0.00224732]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.49648066 -0.0014614 ]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.49814522 -0.00166457]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.5000005  -0.00185528]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.50203263 -0.00203212]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.50422638 -0.00219375]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-0.50756534 -0.00333897]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-0.51202451 -0.00445917]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-0.51757047 -0.00554596]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-0.52416164 -0.00659117]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.53074859 -0.00658695]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.53728192 -0.00653333]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.54271265 -0.00543073]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.54700011 -0.00428746]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.5501122  -0.00311209]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.55202565 -0.00191345]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-0.55472616 -0.00270051]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.55619355 -0.00146739]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.55741687 -0.00122332]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.55838699 -0.00097012]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-5.58096670e-01  2.90319159e-04]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-5.58548078e-01 -4.51408266e-04]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-5.58737847e-01 -1.89768483e-04]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.55766456  0.00107329]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.55533622  0.00232834]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.55177022  0.00356601]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.54699318  0.00477704]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.54204082  0.00495236]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.53595022  0.0060906 ]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.52976701  0.00618321]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.52353753  0.00622947]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.51730852  0.00622901]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.51112668  0.00618184]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.50503836  0.00608832]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.49808917  0.00694919]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.49133111  0.00675805]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.48481469  0.00651643]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-0.47958848  0.0052262 ]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-0.4756914   0.00389708]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-0.47315239  0.00253901]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.47099029  0.00216211]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.46822111  0.00276918]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.46486535  0.00335575]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-0.46294782  0.00191753]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.46148267  0.00146515]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-4.61480696e-01  1.97377074e-06]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-4.61941916e-01 -4.61219964e-04]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-0.46386293 -0.00192101]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-0.46722957 -0.00336664]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.47001696 -0.0027874 ]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-0.4742045  -0.00418753]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.47876113 -0.00455663]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-0.48465303 -0.0058919 ]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-0.49183636 -0.00718333]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-0.50025755 -0.00842119]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.50785366 -0.00759611]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.51456781 -0.00671415]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-0.52234968 -0.00778187]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.53014092 -0.00779124]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-0.5388831  -0.00874218]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.54751069 -0.00862759]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.55595909 -0.0084484 ]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.56416517 -0.00820608]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 2
# observation: [-0.57106775 -0.00690258]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 0
# observation: [-0.57861552 -0.00754777]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
# action: 1
# observation: [-0.58575253 -0.00713701]
# reward: -1.0
# done: False
# info: {}
# ------------------------------
